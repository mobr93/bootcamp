# %% [markdown]
# # nagłowek 1-go poziomu
# ## nagłówek drugiego poziomu
# ### nagłówek 3-go poziomu
# #### nagłówek 4-go poziomiu itd do 6-go poziomu

# %%
name='asd'
print(name)
# Out:
# asd

# %% [markdown]
# * pierwszy
# * drugi
# * trzeci

# %% [markdown]
# 3. pierwszy
# 1. trzeci
# 2. drugi

# %% [markdown]
# *italic*
# **bold**
#
# asda robi 'print()' na ekranie

# %%
        print(name)
# Out:
# asd

# %%
print??

# %%
if True:
    print(name)
# Out:
# asd

# %%
# przydatne - przekazuje systemowe instrukcje do pythona
pliki=!ls

# %%
print(pliki)
# Out:
# ['2019_Moduł_0_Data_Science.pdf', 'dzień2.ipynb', 'GIT', 'Harmonogram grupa I.pdf', 'Matt Harasymczuk sylwetka trenera.pdf', 'Środowisko instalacyjne dla bootcampu Data Science 2019.pdf', 'terminal', 'zadania  mo', 'zajecia1.odt', 'zajęcia2.odt']

# %%
# %%timeit

a=set()
a.add(1)
a.add(2)
# Out:
# 217 ns ± 7.36 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit

b=set()
b.update({1,2})
# Out:
# 235 ns ± 5.56 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit

c=set()
c.update((1,2))
# Out:
# 219 ns ± 4.19 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit

d=set()
d.update([1,2])
# Out:
# 255 ns ± 5.85 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# | imie | nazwisko |
# |------|----------|
# |Jose  | Jimenes  |
# |Jan   | Twardowski|

# %% [markdown]
# %%latex
#
# $$c = \sqrt{a^2 + b^2}$$

# %%
# %%latex
#
# \begin{equation}
# H← ​​​60 ​+​ \frac{​​30(B-R)​​}{Vmax-Vmin}  ​​, if V​max​​ = G
# \end{equation}
# Out:
# \begin{equation}
# H← ​​​60 ​+​ \frac{​​30(B-R)​​}{Vmax-Vmin}  ​​, if V​max​​ = G
# \end{equation}

# %%
# %matplotlib inline

import math
import random
from matplotlib import pyplot as plt

x1 = [x*0.01 for x in range(0,628)]
y1 = [math.sin(x*0.01)+random.gauss(0, 0.1) for x in range(0,628)]
plt.plot(x1, y1)

x2 = [x*0.5 for x in range(0,round(63/5))]
y2 = [math.cos(x*0.5) for x in range(0,round(63/5))]
plt.plot(x2, y2, 'o-')

plt.show()

# %%
url = 'https://raw.githubusercontent.com/scikit-learn/scikit-learn/master/sklearn/datasets/data/iris.csv'
columns = [
    'Sepal length',
    'Sepal width',
    'Petal length',
    'Petal width',
    'Species'
]

# %%
import pandas as pd

# %%
df = pd.read_csv(url, skiprows=1, names=columns)

# %%
df
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# 5             5.4          3.9           1.7          0.4        0
# 6             4.6          3.4           1.4          0.3        0
# 7             5.0          3.4           1.5          0.2        0
# 8             4.4          2.9           1.4          0.2        0
# 9             4.9          3.1           1.5          0.1        0
# 10            5.4          3.7           1.5          0.2        0
# 11            4.8          3.4           1.6          0.2        0
# 12            4.8          3.0           1.4          0.1        0
# ...

# %%
df[df['Sepal length']>5.0]
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  Species
# 0             5.1          3.5           1.4          0.2        0
# 5             5.4          3.9           1.7          0.4        0
# 10            5.4          3.7           1.5          0.2        0
# 14            5.8          4.0           1.2          0.2        0
# 15            5.7          4.4           1.5          0.4        0
# 16            5.4          3.9           1.3          0.4        0
# 17            5.1          3.5           1.4          0.3        0
# 18            5.7          3.8           1.7          0.3        0
# 19            5.1          3.8           1.5          0.3        0
# 20            5.4          3.4           1.7          0.2        0
# 21            5.1          3.7           1.5          0.4        0
# 23            5.1          3.3           1.7          0.5        0
# 27            5.2          3.5           1.5          0.2        0
# ...

# %%
df.Species.replace(to_replace={
    0: 'setosa',
    1: 'versicolor',
    2: 'virginica'
}, inplace=True)

# %%
df
# Out:
#      Sepal length  Sepal width  Petal length  Petal width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
df.sample() # jeden losowy wierszy
df.sample(frac=0.1) #10%
# Out:
#      Sepal length  Sepal width  Petal length  Petal width     Species
# 66            5.6          3.0           4.5          1.5  versicolor
# 6             4.6          3.4           1.4          0.3      setosa
# 123           6.3          2.7           4.9          1.8   virginica
# 100           6.3          3.3           6.0          2.5   virginica
# 79            5.7          2.6           3.5          1.0  versicolor
# 118           7.7          2.6           6.9          2.3   virginica
# 44            5.1          3.8           1.9          0.4      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# 128           6.4          2.8           5.6          2.1   virginica
# 77            6.7          3.0           5.0          1.7  versicolor
# 133           6.3          2.8           5.1          1.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# ...

# %%
df.describe()
# Out:
#        Sepal length  Sepal width  Petal length  Petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faba2518a20>,
# ...
#       dtype=object)

# %%
# 4.5.3. Assignments

INPUT = [
    ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species'),
    (5.8, 2.7, 5.1, 1.9, 'virginica'),
    (5.1, 3.5, 1.4, 0.2, 'setosa'),
    (5.7, 2.8, 4.1, 1.3, 'versicolor'),
    (6.3, 2.9, 5.6, 1.8, 'virginica'),
    (6.4, 3.2, 4.5, 1.5, 'versicolor'),
    (4.7, 3.2, 1.3, 0.2, 'setosa'),
    (7.0, 3.2, 4.7, 1.4, 'versicolor'),
    (7.6, 3.0, 6.6, 2.1, 'virginica'),
    (4.9, 3.0, 1.4, 0.2, 'setosa'),
    (4.9, 2.5, 4.5, 1.7, 'virginica'),
    (7.1, 3.0, 5.9, 2.1, 'virginica'),
    (4.6, 3.4, 1.4, 0.3, 'setosa'),
    (5.4, 3.9, 1.7, 0.4, 'setosa'),
    (5.7, 2.8, 4.5, 1.3, 'versicolor'),
    (5.0, 3.6, 1.4, 0.3, 'setosa'),
    (5.5, 2.3, 4.0, 1.3, 'versicolor'),
    (6.5, 3.0, 5.8, 2.2, 'virginica'),
    (6.5, 2.8, 4.6, 1.5, 'versicolor'),
    (6.3, 3.3, 6.0, 2.5, 'virginica'),
    (6.9, 3.1, 4.9, 1.5, 'versicolor'),
    (4.6, 3.1, 1.5, 0.2, 'setosa'),
]

# %%
header=INPUT[0]

# %%
header
# Out:
# ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species')

# %%
#sposób 1

output=list()
output.append(list(INPUT[2]))
output.append(list(INPUT[6]))
output.append(list(INPUT[9]))

output.append(tuple(INPUT[12]))
output.append(tuple(INPUT[15]))
output.append(tuple(INPUT[16]))

output.append(set())

# %%
output
# Out:
# [[5.1, 3.5, 1.4, 0.2, 'setosa'],
#  [4.7, 3.2, 1.3, 0.2, 'setosa'],
#  [4.9, 3.0, 1.4, 0.2, 'setosa'],
#  (4.6, 3.4, 1.4, 0.3, 'setosa'),
#  (5.0, 3.6, 1.4, 0.3, 'setosa'),
#  (5.5, 2.3, 4.0, 1.3, 'versicolor'),
#  set()]

# %%
#sposób 2 - szybszy

output=[
    list(INPUT[2]),
    list(INPUT[6]),
    list(INPUT[9]),
    tuple(INPUT[12]),
    tuple(INPUT[15]),
    tuple(INPUT[16]),
    set()
]

# %%
output
# Out:
# [[5.1, 3.5, 1.4, 0.2, 'setosa'],
#  [4.7, 3.2, 1.3, 0.2, 'setosa'],
#  [4.9, 3.0, 1.4, 0.2, 'setosa'],
#  (4.6, 3.4, 1.4, 0.3, 'setosa'),
#  (5.0, 3.6, 1.4, 0.3, 'setosa'),
#  (5.5, 2.3, 4.0, 1.3, 'versicolor'),
#  set()]

# %%
# 4.6.11. Assignments
a=(0,1,2,3)
b=[2,3,4,5]
c=set()
c.update(a[::2],b[::2])
c
# Out:
# {0, 2, 4}

# %%
## zad 2

header=INPUT[0]
data=INPUT[1:]
#INPUT['Sepal length'].count
podzial=len(data)*0.6
print(podzial)
trening=data[0:int(podzial)]
test=data[int(podzial):]
#podzial
# Out:
# 12.6

# %%
trening
# Out:
# [(5.8, 2.7, 5.1, 1.9, 'virginica'),
#  (5.1, 3.5, 1.4, 0.2, 'setosa'),
#  (5.7, 2.8, 4.1, 1.3, 'versicolor'),
#  (6.3, 2.9, 5.6, 1.8, 'virginica'),
#  (6.4, 3.2, 4.5, 1.5, 'versicolor'),
#  (4.7, 3.2, 1.3, 0.2, 'setosa'),
#  (7.0, 3.2, 4.7, 1.4, 'versicolor'),
#  (7.6, 3.0, 6.6, 2.1, 'virginica'),
#  (4.9, 3.0, 1.4, 0.2, 'setosa'),
#  (4.9, 2.5, 4.5, 1.7, 'virginica'),
#  (7.1, 3.0, 5.9, 2.1, 'virginica'),
#  (4.6, 3.4, 1.4, 0.3, 'setosa')]

# %%
test
# Out:
# [(5.4, 3.9, 1.7, 0.4, 'setosa'),
#  (5.7, 2.8, 4.5, 1.3, 'versicolor'),
#  (5.0, 3.6, 1.4, 0.3, 'setosa'),
#  (5.5, 2.3, 4.0, 1.3, 'versicolor'),
#  (6.5, 3.0, 5.8, 2.2, 'virginica'),
#  (6.5, 2.8, 4.6, 1.5, 'versicolor'),
#  (6.3, 3.3, 6.0, 2.5, 'virginica'),
#  (6.9, 3.1, 4.9, 1.5, 'versicolor'),
#  (4.6, 3.1, 1.5, 0.2, 'setosa')]

# %%
# zad 3
INPUT = (
    5.8, 2.7, 5.1, 1.9, 'virginica',
    5.1, 3.5, 1.4, 0.2, 'setosa',
    5.7, 2.8, 4.1, 1.3, 'versicolor',
    6.3, 2.9, 5.6, 1.8, 'virginica',
    6.4, 3.2, 4.5, 1.5, 'versicolor',
    4.7, 3.2, 1.3, 0.2, 'setosa',
)

# %%
features=[]
features=[
    tuple(INPUT[0:4]),
    tuple(INPUT[5:9]),
    tuple(INPUT[10:14]),
    tuple(INPUT[15:19]),
    tuple(INPUT[20:24]),
    tuple(INPUT[25:29])
]
features
# Out:
# [(5.8, 2.7, 5.1, 1.9),
#  (5.1, 3.5, 1.4, 0.2),
#  (5.7, 2.8, 4.1, 1.3),
#  (6.3, 2.9, 5.6, 1.8),
#  (6.4, 3.2, 4.5, 1.5),
#  (4.7, 3.2, 1.3, 0.2)]

# %%
labels=INPUT[4::5]
labels
# Out:
# ('virginica', 'setosa', 'versicolor', 'virginica', 'versicolor', 'setosa')

# %%
specials=set(labels)
specials
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %%
# 4.7.6. Assignments
#zad 1
# Polish

#         Podziel dane wejściowe (patrz poniżej) po białych znakach

#         Odseparuj adres ip i nazw hostów

#         Skorzystaj z notacji z gwiazdką *


INPUT = '10.13.37.1      nasa.gov esa.int roscosmos.ru'

# %%
ip, *hosts = INPUT.split()

# %%
ip
# Out:
# '10.13.37.1'

# %%
hosts
# Out:
# ['nasa.gov', 'esa.int', 'roscosmos.ru']

# %%
# zadanie 2
# Polish

#         Dla danych wejściowych (patrz poniżej)

#         Oddziel nagłówek i rekordy

#         Skorzystaj z konstrukcji z gwiazdką *



INPUT: list = [
    ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species'),
    (5.8, 2.7, 5.1, 1.9, 'virginica'),
    (5.1, 3.5, 1.4, 0.2, 'setosa'),
    (5.7, 2.8, 4.1, 1.3, 'versicolor'),
    (6.3, 2.9, 5.6, 1.8, 'virginica'),
    (6.4, 3.2, 4.5, 1.5, 'versicolor'),
    (4.7, 3.2, 1.3, 0.2, 'setosa'),
    (7.0, 3.2, 4.7, 1.4, 'versicolor'),
    (7.6, 3.0, 6.6, 2.1, 'virginica'),
    (4.9, 3.0, 1.4, 0.2, 'setosa'),
    (4.9, 2.5, 4.5, 1.7, 'virginica'),
    (7.1, 3.0, 5.9, 2.1, 'virginica'),
    (4.6, 3.4, 1.4, 0.3, 'setosa'),
    (5.4, 3.9, 1.7, 0.4, 'setosa'),
    (5.7, 2.8, 4.5, 1.3, 'versicolor'),
    (5.0, 3.6, 1.4, 0.3, 'setosa'),
    (5.5, 2.3, 4.0, 1.3, 'versicolor'),
    (6.5, 3.0, 5.8, 2.2, 'virginica'),
    (6.5, 2.8, 4.6, 1.5, 'versicolor'),
    (6.3, 3.3, 6.0, 2.5, 'virginica'),
    (6.9, 3.1, 4.9, 1.5, 'versicolor'),
    (4.6, 3.1, 1.5, 0.2, 'setosa'),
]

# %%
header, *data = INPUT[0],INPUT[1:]

# %%
header
# Out:
# ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species')

# %%
data
# Out:
# [[(5.8, 2.7, 5.1, 1.9, 'virginica'),
#   (5.1, 3.5, 1.4, 0.2, 'setosa'),
#   (5.7, 2.8, 4.1, 1.3, 'versicolor'),
#   (6.3, 2.9, 5.6, 1.8, 'virginica'),
#   (6.4, 3.2, 4.5, 1.5, 'versicolor'),
#   (4.7, 3.2, 1.3, 0.2, 'setosa'),
#   (7.0, 3.2, 4.7, 1.4, 'versicolor'),
#   (7.6, 3.0, 6.6, 2.1, 'virginica'),
#   (4.9, 3.0, 1.4, 0.2, 'setosa'),
#   (4.9, 2.5, 4.5, 1.7, 'virginica'),
#   (7.1, 3.0, 5.9, 2.1, 'virginica'),
#   (4.6, 3.4, 1.4, 0.3, 'setosa'),
#   (5.4, 3.9, 1.7, 0.4, 'setosa'),
#   (5.7, 2.8, 4.5, 1.3, 'versicolor'),
#   (5.0, 3.6, 1.4, 0.3, 'setosa'),
#   (5.5, 2.3, 4.0, 1.3, 'versicolor'),
#   (6.5, 3.0, 5.8, 2.2, 'virginica'),
#   (6.5, 2.8, 4.6, 1.5, 'versicolor'),
#   (6.3, 3.3, 6.0, 2.5, 'virginica'),
#   (6.9, 3.1, 4.9, 1.5, 'versicolor'),
#   (4.6, 3.1, 1.5, 0.2, 'setosa')]]

# %%
# rozwiązanie 2 - prostsze
header, *data = INPUT

# %%
data
# Out:
# [(5.8, 2.7, 5.1, 1.9, 'virginica'),
#  (5.1, 3.5, 1.4, 0.2, 'setosa'),
#  (5.7, 2.8, 4.1, 1.3, 'versicolor'),
#  (6.3, 2.9, 5.6, 1.8, 'virginica'),
#  (6.4, 3.2, 4.5, 1.5, 'versicolor'),
#  (4.7, 3.2, 1.3, 0.2, 'setosa'),
#  (7.0, 3.2, 4.7, 1.4, 'versicolor'),
#  (7.6, 3.0, 6.6, 2.1, 'virginica'),
#  (4.9, 3.0, 1.4, 0.2, 'setosa'),
#  (4.9, 2.5, 4.5, 1.7, 'virginica'),
#  (7.1, 3.0, 5.9, 2.1, 'virginica'),
#  (4.6, 3.4, 1.4, 0.3, 'setosa'),
#  (5.4, 3.9, 1.7, 0.4, 'setosa'),
#  (5.7, 2.8, 4.5, 1.3, 'versicolor'),
#  (5.0, 3.6, 1.4, 0.3, 'setosa'),
#  (5.5, 2.3, 4.0, 1.3, 'versicolor'),
#  (6.5, 3.0, 5.8, 2.2, 'virginica'),
#  (6.5, 2.8, 4.6, 1.5, 'versicolor'),
#  (6.3, 3.3, 6.0, 2.5, 'virginica'),
#  (6.9, 3.1, 4.9, 1.5, 'versicolor'),
#  (4.6, 3.1, 1.5, 0.2, 'setosa')]

# %%
# dicty
slownik={
'A': 'Alfa',
'B': 'Bravo',
'C': 'Charlie',
'D': 'Delta'
}

# %%
slownik
# Out:
# {'A': 'Alfa', 'B': 'Bravo', 'C': 'Charlie', 'D': 'Delta'}

# %%
litera=input('Podaj literę:')
slownik.get(litera, "Pilots don't say that")
# Out:
# Podaj literę:A
# 'Alfa'

# %%
cyfra=input("podaj liczbę")
int(cyfra)%2==0
# Out:
# podaj liczbę3
# False

# %%
# 6.2.5. Assignments

# %%
wiek=input("podaj wiek:")
PELNOLETNOSC=18
if int(wiek)>=PELNOLETNOSC:
    print("uzytkownik jest pełnoletni")
else:
    print("użytkownik jest niepełnoletni")
# Out:
# podaj wiek:18
# uzytkownik jest pełnoletni

# %%
# zad 7.1.4. Assignments

# %%
INPUT = (2, 3, 3.5, 4, 4.5, 5)
i=0
skala=list()
dziennik=list()
while i<len(INPUT):
    skala.append(float(INPUT[i]))
    i+=1
while True:
    ocena=input("podaj ocene: ")
    if not ocena:
        break
    if float(ocena) in skala:
        dziennik.append(float(ocena))
    elif float(ocena) not in skala:
        print("ocena nie jest na liście")
if dziennik:
    srednia=sum(dziennik)/len(dziennik)
print('srednia= ',srednia)
print('dziennik= ',dziennik)
print('skala= ',skala)
# Out:
# podaj ocene: 2
# podaj ocene: 3
# podaj ocene:
# srednia=  2.5
# dziennik=  [2.0, 3.0]
# skala=  [2.0, 3.0, 3.5, 4.0, 4.5, 5.0]

# %%
# 7.2.5.1. Counter
INPUT = [1, 4, 6, 7, 4, 4, 4, 5, 1, 7, 0,
         0, 6, 5, 0, 0, 9, 7, 0, 4, 4, 8,
         2, 4, 0, 0, 1, 9, 1, 7, 8, 8, 9,
         1, 3, 5, 6, 8, 2, 8, 1, 3, 9, 5,
         4, 8, 1, 9, 6, 3]
slownik=dict()
for cyfra in INPUT:
    if cyfra in slownik:
        slownik[cyfra]+=1
    else:
        slownik[cyfra]=1
print(slownik)
# Out:
# {1: 7, 4: 8, 6: 4, 7: 4, 5: 4, 0: 7, 9: 5, 8: 6, 2: 2, 3: 3}

# %%
#7.2.5.2. Segmentation
INPUT = [1, 4, 6, 7, 4, 4, 4, 5, 1, 7, 0,
         0, 6, 5, 0, 0, 9, 7, 0, 4, 4, 8,
         2, 4, 0, 0, 1, 9, 1, 7, 8, 8, 9,
         1, 3, 5, 6, 8, 2, 8, 1, 3, 9, 5,
         4, 8, 1, 9, 6, 3]

output={
    'small':0,
    'medium':0,
    'large':0
    
}
for cyfra in INPUT:
    if 0<=cyfra<=2:
        output['small']+=1
    if 3<=cyfra<=7:
        output['medium']+=1
    if 8<=cyfra<=9:
        output['large']+=1

print(output)
# Out:
# {'small': 16, 'medium': 23, 'large': 11}

# %%
# 7.2.5.3. Text analysis
# trochę to zadanie niezrozumiałem i rozszerzyłem je o zliczanie wystąpień słow
text='We choose to go to the Moon. We choose to go to the Moon in this decade and do the other things. Not because they are easy, but because they are hard. Because that goal will serve to organize and measure the best of our energies and skills. Because that challenge is one that we are willing to accept. One we are unwilling to postpone. And one we intend to win'
total_przysl=0
total_zdan=0
total_slow=0
total_liter=0
total_znakow=0
total_przecinkow=0
total_przysl=0
total_chars =0
total_commas=0
zdania=text.split('.')

for zdanie in zdania:
    total_zdan+=1
    total_chars += len(zdanie)
    total_commas += zdanie.count(',')
    zdanie=zdanie.strip()
    output={}
    wyrazy=zdanie.split()
    #print(wyrazy)
    for slowo in wyrazy:
        #print(slowo)
        total_slow+=1
        total_liter+=len(slowo)
        if slowo in output:
            output[slowo]+=1
        else:
            output[slowo]=1
        if slowo.endswith('ly'):
            total_przysl += 1
    print(output)
print('total_zdan',total_zdan)
print('total_slow',total_slow)
print('total_liter',total_liter)
print('total_przysl',total_przysl)
print('total_chars',total_chars)
print('total_przecinkow',total_commas)
# Out:
# {'We': 1, 'choose': 1, 'to': 2, 'go': 1, 'the': 1, 'Moon': 1}
# {'We': 1, 'choose': 1, 'to': 2, 'go': 1, 'the': 2, 'Moon': 1, 'in': 1, 'this': 1, 'decade': 1, 'and': 1, 'do': 1, 'other': 1, 'things': 1}
# {'Not': 1, 'because': 2, 'they': 2, 'are': 2, 'easy,': 1, 'but': 1, 'hard': 1}
# {'Because': 1, 'that': 1, 'goal': 1, 'will': 1, 'serve': 1, 'to': 1, 'organize': 1, 'and': 2, 'measure': 1, 'the': 1, 'best': 1, 'of': 1, 'our': 1, 'energies': 1, 'skills': 1}
# {'Because': 1, 'that': 2, 'challenge': 1, 'is': 1, 'one': 1, 'we': 1, 'are': 1, 'willing': 1, 'to': 1, 'accept': 1}
# {'One': 1, 'we': 1, 'are': 1, 'unwilling': 1, 'to': 1, 'postpone': 1}
# {'And': 1, 'one': 1, 'we': 1, 'intend': 1, 'to': 1, 'win': 1}
# total_zdan 7
# total_slow 71
# total_liter 284
# total_przysl 0
# total_chars 354
# total_przecinkow 1

# %%
# zad

# %%
INPUT = [
    ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species'),
    (5.8, 2.7, 5.1, 1.9, {'virginica'}),
    (5.1, 3.5, 1.4, 0.2, {'setosa'}),
    (5.7, 2.8, 4.1, 1.3, {'versicolor'}),
    (6.3, 2.9, 5.6, 1.8, {'virginica'}),
    (6.4, 3.2, 4.5, 1.5, {'versicolor'}),
    (4.7, 3.2, 1.3, 0.2, {'setosa'}),
    (7.0, 3.2, 4.7, 1.4, {'versicolor'}),
    (4.6, 3.1, 1.5, 0.2, {'setosa'}),
]
header=INPUT[0]
dane=INPUT[1:]
dane

# %%
# to nie diząła rozwiązanie moje ;/
# for wiersz in dane:
#     #print(wiersz)
#     for wartosc in wiersz:
#         print(wartosc)
#         if isinstance(wartosc, (str)) and (wartosc.endswith('ca') or wartosc.endswith('sa')):
#             #print(wartosc)
#         for wyraz in wartosc:
#             print(wyraz)
#             if isinstance(wartosc, (str)) and (wyraz.endswith('ca') or wyraz.endswith('sa')):
#                 print(wyraz)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-229-b2691802f325> in <module>
#       5         if isinstance(wartosc, (str)) and (wartosc.endswith('ca') or wartosc.endswith('sa')):
#       6             print(wartosc)
# ----> 7         for wyraz in wartosc:
#       8             print(wyraz)
#       9             if isinstance(wartosc, (str)) and (wyraz.endswith('ca') or wyraz.endswith('sa')):
#
# TypeError: 'float' object is not iterable

# %%
# rozwiązanie lepsze
INPUT = [
    ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species'),
    (5.8, 2.7, 5.1, 1.9, {'virginica'}),
    (5.1, 3.5, 1.4, 0.2, {'setosa'}),
    (5.7, 2.8, 4.1, 1.3, {'versicolor'}),
    (6.3, 2.9, 5.6, 1.8, {'virginica'}),
    (6.4, 3.2, 4.5, 1.5, {'versicolor'}),
    (4.7, 3.2, 1.3, 0.2, {'setosa'}),
    (7.0, 3.2, 4.7, 1.4, {'versicolor'}),
    (7.6, 3.0, 6.6, 2.1, {'virginica'}),
    (4.6, 3.1, 1.5, 0.2, {'setosa'}),
]

# %%
header=INPUT[0]
dane=INPUT[1:]
gatunek={}
for *pomiary,gatunek in dane:
    gatunek=gatunek.pop()
    
    if gatunek.endswith('ca'):
        print(gatunek)
    if gatunek.endswith('sa'):
        print(gatunek)
# Out:
# virginica
# setosa
# virginica
# setosa
# virginica
# setosa

# %%
#zad
INPUT = [
    {'Sepal length': 5.1, 'Sepal width': 3.5, 'Species': 'setosa'},
    {'Petal length': 4.1, 'Petal width': 1.3, 'Species': 'versicolor'},
    {'Sepal length': 6.3, 'Petal width': 1.8, 'Species': 'virginica'},
    {'Sepal length': 5.0, 'Petal width': 0.2, 'Species': 'setosa'},
    {'Sepal width': 2.8, 'Petal length': 4.1, 'Species': 'versicolor'},
    {'Sepal width': 2.9, 'Petal width': 1.8, 'Species': 'virginica'},
]

# %%
klucze=set()
for row in INPUT:
    klucze.update(row.keys())

# %%
klucze
# Out:
# {'Petal length', 'Petal width', 'Sepal length', 'Sepal width', 'Species'}

# %%
# zad
INPUT = {
    6: ['Doctorate', 'Prof-school'],
    5: ['Masters', 'Bachelor', 'Engineer'],
    4: ['HS-grad'],
    3: ['Junior High'],
    2: ['Primary School'],
    1: ['Kindergarten'],
}
#output=list()

# %%
output={}
for key,values in INPUT.items():
    for slowo in values:
        output[slowo]=str(key)
print(output)
# Out:
# {'Doctorate': '6', 'Prof-school': '6', 'Masters': '5', 'Bachelor': '5', 'Engineer': '5', 'HS-grad': '4', 'Junior High': '3', 'Primary School': '2', 'Kindergarten': '1'}

# %%
INPUT = [
    ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species'),
    (5.8, 2.7, 5.1, 1.9, 'virginica'),
    (5.1, 3.5, 1.4, 0.2, 'setosa'),
    (5.7, 2.8, 4.1, 1.3, 'versicolor'),
    (6.3, 2.9, 5.6, 1.8, 'virginica'),
    (6.4, 3.2, 4.5, 1.5, 'versicolor'),
    (4.7, 3.2, 1.3, 0.2, 'setosa'),
    (7.0, 3.2, 4.7, 1.4, 'versicolor'),
    (7.6, 3.0, 6.6, 2.1, 'virginica'),
    (4.9, 3.0, 1.4, 0.2, 'setosa'),
    (4.9, 2.5, 4.5, 1.7, 'virginica'),
    (7.1, 3.0, 5.9, 2.1, 'virginica'),
    (4.6, 3.4, 1.4, 0.3, 'setosa'),
    (5.4, 3.9, 1.7, 0.4, 'setosa'),
    (5.7, 2.8, 4.5, 1.3, 'versicolor'),
    (5.0, 3.6, 1.4, 0.3, 'setosa'),
    (5.5, 2.3, 4.0, 1.3, 'versicolor'),
    (6.5, 3.0, 5.8, 2.2, 'virginica'),
    (6.5, 2.8, 4.6, 1.5, 'versicolor'),
    (6.3, 3.3, 6.0, 2.5, 'virginica'),
    (6.9, 3.1, 4.9, 1.5, 'versicolor'),
    (4.6, 3.1, 1.5, 0.2, 'setosa'),
]

# %%
header=INPUT[0]
dane=INPUT[1:]
output=list()
for row in dane:
    output.append(dict(zip(header,row)))

# %%
output
# Out:
# [{'Sepal length': 5.8,
#   'Sepal width': 2.7,
#   'Petal length': 5.1,
#   'Petal width': 1.9,
#   'Species': 'virginica'},
#  {'Sepal length': 5.1,
#   'Sepal width': 3.5,
#   'Petal length': 1.4,
#   'Petal width': 0.2,
#   'Species': 'setosa'},
#  {'Sepal length': 5.7,
#   'Sepal width': 2.8,
#   'Petal length': 4.1,
#   'Petal width': 1.3,
#   'Species': 'versicolor'},
#  {'Sepal length': 6.3,
#   'Sepal width': 2.9,
#   'Petal length': 5.6,
#   'Petal width': 1.8,
#   'Species': 'virginica'},
#  {'Sepal length': 6.4,
#   'Sepal width': 3.2,
#   'Petal length': 4.5,
#   'Petal width': 1.5,
#   'Species': 'versicolor'},
#  {'Sepal length': 4.7,
#   'Sepal width': 3.2,
#   'Petal length': 1.3,
#   'Petal width': 0.2,
#   'Species': 'setosa'},
#  {'Sepal length': 7.0,
#   'Sepal width': 3.2,
#   'Petal length': 4.7,
#   'Petal width': 1.4,
#   'Species': 'versicolor'},
#  {'Sepal length': 7.6,
#   'Sepal width': 3.0,
#   'Petal length': 6.6,
#   'Petal width': 2.1,
# ...

# %%
# zad 2
INPUT = [
    ('Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species'),
    (5.8, 2.7, 5.1, 1.9, 'virginica'),
    (5.1, 3.5, 1.4, 0.2, 'setosa'),
    (5.7, 2.8, 4.1, 1.3, 'versicolor'),
    (6.3, 2.9, 5.6, 1.8, 'virginica'),
    (6.4, 3.2, 4.5, 1.5, 'versicolor'),
    (4.7, 3.2, 1.3, 0.2, 'setosa'),
    (7.0, 3.2, 4.7, 1.4, 'versicolor'),
    (7.6, 3.0, 6.6, 2.1, 'virginica'),
    (4.9, 3.0, 1.4, 0.2, 'setosa'),
    (4.9, 2.5, 4.5, 1.7, 'virginica'),
    (7.1, 3.0, 5.9, 2.1, 'virginica'),
    (4.6, 3.4, 1.4, 0.3, 'setosa'),
    (5.4, 3.9, 1.7, 0.4, 'setosa'),
    (5.7, 2.8, 4.5, 1.3, 'versicolor'),
    (5.0, 3.6, 1.4, 0.3, 'setosa'),
    (5.5, 2.3, 4.0, 1.3, 'versicolor'),
    (6.5, 3.0, 5.8, 2.2, 'virginica'),
    (6.5, 2.8, 4.6, 1.5, 'versicolor'),
    (6.3, 3.3, 6.0, 2.5, 'virginica'),
    (6.9, 3.1, 4.9, 1.5, 'versicolor'),
    (4.6, 3.1, 1.5, 0.2, 'setosa'),
]
from typing import List, Tuple, Dict

header = INPUT[0]
data = INPUT[1:]

features: List[Tuple[float]] = []
labels: List[int] = []

label_encoder: Dict[int, str] = {}


for row in data:
    measurements = row[0:4]
    species = row[4]
    features.append(tuple(measurements))

    if species not in label_encoder.values():
        number = len(label_encoder)
        label_encoder[number] = species

    for number, name in label_encoder.items():
        if name == species:
            labels.append(number)


print(features)
print()
print(labels)
print()
print(label_encoder)
# Out:
# [(5.8, 2.7, 5.1, 1.9), (5.1, 3.5, 1.4, 0.2), (5.7, 2.8, 4.1, 1.3), (6.3, 2.9, 5.6, 1.8), (6.4, 3.2, 4.5, 1.5), (4.7, 3.2, 1.3, 0.2), (7.0, 3.2, 4.7, 1.4), (7.6, 3.0, 6.6, 2.1), (4.9, 3.0, 1.4, 0.2), (4.9, 2.5, 4.5, 1.7), (7.1, 3.0, 5.9, 2.1), (4.6, 3.4, 1.4, 0.3), (5.4, 3.9, 1.7, 0.4), (5.7, 2.8, 4.5, 1.3), (5.0, 3.6, 1.4, 0.3), (5.5, 2.3, 4.0, 1.3), (6.5, 3.0, 5.8, 2.2), (6.5, 2.8, 4.6, 1.5), (6.3, 3.3, 6.0, 2.5), (6.9, 3.1, 4.9, 1.5), (4.6, 3.1, 1.5, 0.2)]
#
# [0, 1, 2, 0, 2, 1, 2, 0, 1, 0, 0, 1, 1, 2, 1, 2, 0, 2, 0, 2, 1]
#
# {0: 'virginica', 1: 'setosa', 2: 'versicolor'}
